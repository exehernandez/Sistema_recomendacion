# %%
import pandas as pd
import tkinter as tk
from tkinter import simpledialog
import ast

# %%
sypnopsis = pd.read_csv(r"D:\Exe\OneDrive - alumnos.frm.utn.edu.ar\Cursos\Data Science\TP4\Dataset\anime_with_synopsis.csv")
sypnopsis
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 16209   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16210   48483                     Mieruko-chan  Unknown
# 16211   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 16212   48491      Yama no Susume: Next Summit  Unknown
# 16213   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
sypnopsis = sypnopsis[["MAL_ID", "sypnopsis"]]
sypnopsis
# Out:
#        MAL_ID                                          sypnopsis
# 0           1  In the year 2071, humanity has colonized sever...
# 1           5  other day, another bounty—such is the life of ...
# 2           6  Vash the Stampede is the man with a $$60,000,0...
# 3           7  ches are individuals with special powers like ...
# 4           8  It is the dark century and the people are suff...
# ...       ...                                                ...
# 16209   48481  No synopsis information has been added to this...
# 16210   48483  ko is a typical high school student whose life...
# 16211   48488          Sequel to Higurashi no Naku Koro ni Gou .
# 16212   48491                          New Yama no Susume anime.
# 16213   48492  Solar calendar year 2020: grotesque organisms ...
#
# [16214 rows x 2 columns]

# %%
anime_info = pd.read_csv(r"D:\Exe\OneDrive - alumnos.frm.utn.edu.ar\Cursos\Data Science\TP4\Dataset\anime.csv")
anime_info
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 17558   48483                     Mieruko-chan  Unknown
# 17559   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 17560   48491      Yama no Susume: Next Summit  Unknown
# 17561   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
anime_info = anime_info[["MAL_ID"	,"Name","Genres" ,"Type",	"Episodes"]]
anime_info
# Out:
#        MAL_ID                             Name  \
# 0           1                     Cowboy Bebop
# 1           5  Cowboy Bebop: Tengoku no Tobira
# 2           6                           Trigun
# 3           7               Witch Hunter Robin
# 4           8                   Bouken Ou Beet
# ...       ...                              ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu
# 17558   48483                     Mieruko-chan
# 17559   48488  Higurashi no Naku Koro ni Sotsu
# 17560   48491      Yama no Susume: Next Summit
# 17561   48492                    Scarlet Nexus
#
#                                                   Genres   Type Episodes
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26
# 1                  Action, Drama, Mystery, Sci-Fi, Space  Movie        1
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen     TV       26
# 3      Action, Mystery, Police, Supernatural, Drama, ...     TV       26
# ...

# %%
df = pd.merge(anime_info, sypnopsis, on="MAL_ID")
df
# Out:
#        MAL_ID                             Name  \
# 0           1                     Cowboy Bebop
# 1           5  Cowboy Bebop: Tengoku no Tobira
# 2           6                           Trigun
# 3           7               Witch Hunter Robin
# 4           8                   Bouken Ou Beet
# ...       ...                              ...
# 16209   48481  Daomu Biji Zhi Qinling Shen Shu
# 16210   48483                     Mieruko-chan
# 16211   48488  Higurashi no Naku Koro ni Sotsu
# 16212   48491      Yama no Susume: Next Summit
# 16213   48492                    Scarlet Nexus
#
#                                                   Genres   Type Episodes  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26
# 1                  Action, Drama, Mystery, Sci-Fi, Space  Movie        1
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen     TV       26
# 3      Action, Mystery, Police, Supernatural, Drama, ...     TV       26
# ...

# %%
df = df.rename(columns={'MAL_ID': 'anime_id', 'Name' : 'name', 'Genres' : 'genres',
                        'Type' : 'type', 'Episodes' : 'episodes'})
df
# Out:
#        anime_id                             name  \
# 0             1                     Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira
# 2             6                           Trigun
# 3             7               Witch Hunter Robin
# 4             8                   Bouken Ou Beet
# ...         ...                              ...
# 16209     48481  Daomu Biji Zhi Qinling Shen Shu
# 16210     48483                     Mieruko-chan
# 16211     48488  Higurashi no Naku Koro ni Sotsu
# 16212     48491      Yama no Susume: Next Summit
# 16213     48492                    Scarlet Nexus
#
#                                                   genres   type episodes  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26
# 1                  Action, Drama, Mystery, Sci-Fi, Space  Movie        1
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen     TV       26
# 3      Action, Mystery, Police, Supernatural, Drama, ...     TV       26
# ...

# %%
df.to_csv("base_de_datos.csv", index=False)

# %%
df.isna().sum()
# Out:
# anime_id     0
# name         0
# genres       0
# type         0
# episodes     0
# sypnopsis    8
# dtype: int64

# %%
df["anime_id"].nunique()
# Out:
# 16214

# %%
base_de_datos = pd.read_csv(r"D:\Exe\OneDrive - alumnos.frm.utn.edu.ar\Cursos\Data Science\TP4\Entrega\base_de_datos.csv")
base_de_datos.head()
# Out:
#    anime_id                             name  \
# 0         1                     Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira
# 2         6                           Trigun
# 3         7               Witch Hunter Robin
# 4         8                   Bouken Ou Beet
#
#                                               genres   type episodes  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26
# 1              Action, Drama, Mystery, Sci-Fi, Space  Movie        1
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen     TV       26
# 3  Action, Mystery, Police, Supernatural, Drama, ...     TV       26
# 4          Adventure, Fantasy, Shounen, Supernatural     TV       52
#
#                                            sypnopsis
# 0  In the year 2071, humanity has colonized sever...
# 1  other day, another bounty—such is the life of ...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  ches are individuals with special powers like ...
# ...

# %%
recomendaciones = pd.read_csv(r"D:\Exe\OneDrive - alumnos.frm.utn.edu.ar\Cursos\Data Science\TP4\Entrega\recomedaciones.csv")
recomendaciones.head()
# Out:
#    user_id                                            recomms
# 0   323567  [34235, 33857, 36315, 30131, 35155, 39778, 352...
# 1   189037  [34235, 33857, 36315, 30131, 35155, 39778, 352...
# 2   127483  [34235, 33857, 36315, 30131, 35155, 39778, 352...
# 3    68042  [34235, 33857, 36315, 30131, 35155, 39778, 352...
# 4   312302  [34235, 33857, 36315, 30131, 35155, 39778, 352...

# %%
base_de_datos[base_de_datos.anime_id == 34235]
# Out:
#        anime_id                  name        genres type episodes  \
# 11180     34235  Pittanko! Nekozakana  Comedy, Kids   TV       50
#
#                                                sypnopsis
# 11180  On a distant southern island, a fish (sakana) ...

# %% [markdown]
# ## DataFrames COLD START

# %%
mov = pd.read_csv(r"D:\Exe\OneDrive - alumnos.frm.utn.edu.ar\Cursos\Data Science\TP4\Entrega\Cold Start\ListAuto_Mov20.csv")
ona = pd.read_csv(r"D:\Exe\OneDrive - alumnos.frm.utn.edu.ar\Cursos\Data Science\TP4\Entrega\Cold Start\ListAuto_ONA20.csv")
ova = pd.read_csv(r"D:\Exe\OneDrive - alumnos.frm.utn.edu.ar\Cursos\Data Science\TP4\Entrega\Cold Start\ListAuto_OVA20.csv")
special = pd.read_csv(r"D:\Exe\OneDrive - alumnos.frm.utn.edu.ar\Cursos\Data Science\TP4\Entrega\Cold Start\ListAuto_Special20.csv")
tv = pd.read_csv(r"D:\Exe\OneDrive - alumnos.frm.utn.edu.ar\Cursos\Data Science\TP4\Entrega\Cold Start\ListAuto_TV20.csv")

# %%
mov_df = pd.merge(mov, base_de_datos, left_on='Name', right_on='name')
mov_df = mov_df.drop(['Name', 'type'], axis=1)
mov_df
# Out:
#     anime_id                                               name  \
# 0      40456           Kimetsu no Yaiba Movie: Mugen Ressha-hen
# 1      32281                                     Kimi no Na wa.
# 2       7311                      Suzumiya Haruhi no Shoushitsu
# 3      28851                                     Koe no Katachi
# 4      36862   Made in Abyss Movie 3: Fukaki Tamashii no Reimei
# 5      38040  Kono Subarashii Sekai ni Shukufuku wo!: Kurena...
# 6      37987                            Violet Evergarden Movie
# 7      33674                              No Game No Life: Zero
# 8        451               InuYasha Movie 3: Tenka Hadou no Ken
# 9      39486                                 Gintama: The Final
# 10       164                                      Mononoke Hime
# 11     15335  Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...
# 12       450        InuYasha Movie 2: Kagami no Naka no Mugenjo
# 13     38826                                        Tenki no Ko
# ...

# %%
ona_df = pd.merge(ona, base_de_datos, left_on='Name', right_on='name')
ona_df = ona_df.drop(['Name', 'type'], axis=1)
ona_df
# Out:
#     anime_id                                            name  \
# 0      40052                                 Great Pretender
# 1      37208                                   Mo Dao Zu Shi
# 2      40861                              Hakumei no Tsubasa
# 3      35120                               Devilman: Crybaby
# 4      28149                        Nihon Animator Mihonichi
# 5      38409                                   Cike Wu Liuqi
# 6      40784              Wu Liuqi Zhi Zui Qiang Fa Xing Shi
# 7      40730                                 Tian Guan Ci Fu
# 8      40542              Saiki Kusuo no Ψ-nan: Ψ-shidou-hen
# 9      42498                      Douluo Dalu: Xiaowu Juebie
# 10     42497                    Douluo Dalu: Qian Hua Xi Jin
# 11     37822                       Douluo Dalu: Jingying Sai
# 12     38250                             Xiao Lu He Xiao Lan
# 13     41168               Nakitai Watashi wa Neko wo Kaburu
# ...

# %%
ova_df = pd.merge(ova, base_de_datos, left_on='Name', right_on='name')
ova_df = ova_df.drop(['Name', 'type'], axis=1)
ova_df
# Out:
#     anime_id                                               name  \
# 0        227                                               FLCL
# 1        820                               Ginga Eiyuu Densetsu
# 2        777                                  Hellsing Ultimate
# 3         44  Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...
# 4        949                            Top wo Nerae! Gunbuster
# 5       4938                                 Tsubasa: Shunraiki
# 6       5781                      Isekai no Seikishi Monogatari
# 7      28285  Trinity Seven: Nanatsu no Taizai to Nana Madoushi
# 8      23317                       Kuroshitsuji: Book of Murder
# 9       2685                         Tsubasa: Tokyo Revelations
# 10      8740             One Piece Film: Strong World Episode 0
# 11     36480                                     Drifters (OVA)
# 12     30885                               Noragami Aragoto OVA
# 13     30709                   Kamisama Hajimemashita: Kako-hen
# ...

# %%
special_df = pd.merge(special, base_de_datos, left_on='Name', right_on='name')
special_df = special_df.drop(['Name', 'type'], axis=1)
special_df
# Out:
#     anime_id                                               name  \
# 0      19123  One Piece: Episode of Merry - Mou Hitori no Na...
# 1      15323  One Piece: Episode of Nami - Koukaishi no Nami...
# 2      36215  One Piece: Episode of East Blue - Luffy to 4-n...
# 3      31289  One Piece: Episode of Sabo - 3 Kyoudai no Kizu...
# 4       2832                                         Ani*Kuri15
# 5       6489  Zero no Tsukaima: Princesses no Rondo Picture ...
# 6      33338                           One Piece: Heart of Gold
# 7       2951  Gintama: Nanigoto mo Saiyo ga Kanjin nano de T...
# 8       9735                   Gintama: Shinyaku Benizakura-hen
# 9      21329                               Mushishi: Hihamukage
# 10     20159                                Pokemon: The Origin
# 11      4886                           InuYasha: Kuroi Tessaiga
# 12     44087                            Gintama: The Semi-Final
# 13     16001                       Kokoro Connect: Michi Random
# ...

# %%
tv_df = pd.merge(tv, base_de_datos, left_on='Name', right_on='name')
tv_df = tv_df.drop(['Name', 'type'], axis=1)
tv_df
# Out:
#     anime_id                              name  \
# 0       5114  Fullmetal Alchemist: Brotherhood
# 1          1                      Cowboy Bebop
# 2       9253                       Steins;Gate
# 3        918                           Gintama
# 4       2001        Tengen Toppa Gurren Lagann
# 5      11061            Hunter x Hunter (2011)
# 6        457                          Mushishi
# 7       2251                          Baccano!
# 8       4181              Clannad: After Story
# 9      13601                       Psycho-Pass
# 10      2167                           Clannad
# 11       205                  Samurai Champloo
# 12      1575   Code Geass: Hangyaku no Lelouch
# 13      6547                      Angel Beats!
# 14     20507                          Noragami
# 15     23273           Shigatsu wa Kimi no Uso
# 16     28977                          Gintama°
# 17     34599                     Made in Abyss
# 18        21                         One Piece
# ...

# %%
# mov_df.to_csv("mov_df.csv", index=False)
# ona_df.to_csv("ona_df.csv", index=False)
# ova_df.to_csv("ova_df.csv", index=False)
# special_df.to_csv("special_df.csv", index=False)
# tv_df.to_csv("tv_df.csv", index=False)

# %% [markdown]
# ## Sistema de impresión de recomendaciones

# %%
# Función para obtener el user_id ingresado por el usuario
def obtener_user_id():
    root = tk.Tk()
    root.withdraw()
    user_id = simpledialog.askinteger("Input", "Ingrese el user_id:")
    return user_id

# %%
# Obtener el user_id desde la ventana de entrada
user_id = obtener_user_id()

# %%
recomendaciones.user_id.values
# Out:
# array([323567, 189037, 127483,  68042, 312302, 300428,  71931, 162615,
#        328195,  38143, 259790,  64807, 345498,   4773,  76674, 107014,
#        190748,  85106, 182280, 107650, 320669, 341571, 336459, 135337,
#        173716,  18355, 276953, 194781, 299795, 122341,  10255, 291207,
#        283786, 275125,  25411, 321704, 328108,  55748, 203453, 277841,
#        102250, 261827, 316154], dtype=int64)

# %%
if user_id in recomendaciones.user_id.values:
    # Obtener las recomendaciones para el user_id ingresado
    recomendaciones_usuario = recomendaciones[recomendaciones['user_id'] == user_id]['recomms'].values[0]
    recomendaciones_usuario = ast.literal_eval(recomendaciones_usuario)

    # Filtrar base_de_datos según las recomendaciones para el user_id ingresado
    df_resultado = base_de_datos[base_de_datos['anime_id'].isin(recomendaciones_usuario)]
    # Ordenar df_resultado por la columna anime_id según el orden de recomendaciones
    df_resultado = df_resultado.sort_values(by='anime_id', key=lambda x: x.map({anime_id: i for i, anime_id in enumerate(recomendaciones_usuario)})).reset_index(drop=True).head(20)
    print("Las 20 recomendaciones para el usuario", user_id, "son:")
    df_resultado
else:
     # Si el user_id no está en la base de datos, imprimir mensaje de COLD START
    print("El usuario es COLD START. Se recomienda el siguiente contenido")
    print("Recomendaciones MOV:")
    print(mov_df.to_string)
    print("Recomendaciones ONA:")
    print(ona_df.to_string())
    print("Recomendaciones OVA:")
    print(ova_df.to_string())
    print("Recomendaciones SPECIAL:")
    print(special_df.to_string())
    print("Recomendaciones TV:")
    print(tv_df.to_string())
# Out:
# Las 20 recomendaciones para el usuario 323567 son:

# %%
# Out:
# Las 20 recomendaciones para el usuario 323567 son:
#     anime_id                                               name  \
# 0      34235                               Pittanko! Nekozakana
# 1      33857  Saitama-ken Zaijuu, Fujiyama Osamu, 33-sai, Mu...
# 2      36315  Mushi Mushi Mura no Nakama-tachi: Minna Ii Tok...
# 3      30131                                       Uwabaki Cook
# 4      35155                         Kurayami wa Kiken ga Ippai
# 5      39778                                        Skyers 5 EX
# 6      35273               Ponkaman no Animation no Dekiru made
# 7      31004                                  Niji no Kakehashi
# 8      33604                          Mo Jing Lieren 3rd Season
# 9      34182                               Nikoniko♪Connie-chan
# 10     35543                          Turning Mecard W Season 2
# 11     33826                             Neko no Kuni no Kenpou
# 12     36311                            Mirai Shouboushi Kyuuta
# ...
